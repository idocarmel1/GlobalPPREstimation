# %% [markdown]
# # PPR global_te005 validation
#
# This notebook validates all 66 LMEs and 18 High Seas units at TE=0.05 using the Sea Around Us definitions. Catch includes landings and discards, reported and unreported, for the latest year shared by every archive.
#
# Only the approved Pauly-Christensen trophic-chain calculation is used:
#
# \[
# SPPR = 10^{TL-1}
# \]
#
# \[
# PPR = Catch_{tonnes} \times SPPR
# \]
#
# The separate wet-weight-to-carbon divisor of 9 is intentionally omitted. PPR is reported in tonnes of primary-production equivalent.

# %%
from pathlib import Path
import json
import pandas as pd
import matplotlib.pyplot as plt

ROOT = Path.cwd()
if not (ROOT / 'global_output_te005' / 'tables').exists():
    ROOT = ROOT.parent
TABLES = ROOT / 'global_output_te005' / 'tables'
metadata = json.loads((TABLES / 'run_metadata.json').read_text())
print(f"Scope: {metadata['scope']} | Units: {metadata['unit_count']} | Year: {metadata['year']} | TE: {metadata['transfer_efficiency']}")
# Out:
# Scope: all Sea Around Us LMEs and High Seas units | Units: 84 | Year: 2019 | TE: 0.05

# %% [markdown]
# ## Global ranking and catch totals

# %%
summary = pd.read_csv(TABLES / 'global_te005_summary.csv')
display(summary[['rank_global_te005_ppr', 'unit_id', 'region_name', 'region_type', 'year',
                 'total_catch_tonnes', 'catch_tl_coverage_fraction', 'ppr_species',
                 'fraction_global_te005_ppr']].head(25))

top = summary.nsmallest(25, 'rank_global_te005_ppr').sort_values('ppr_species')
ax = top.plot.barh(x='region_name', y='ppr_species', legend=False,
                   color='#147D92', figsize=(10, 9))
ax.set_title(f"Top 25 PPR spatial units ({metadata['year']})")
ax.set_xlabel('tonnes primary-production equivalent')
ax.set_ylabel('')
plt.tight_layout()
plt.show()

display(summary.groupby('region_type', as_index=False).agg(
    units=('unit_id', 'size'), catch_tonnes=('total_catch_tonnes', 'sum'),
    ppr=('ppr_species', 'sum')))
# Out:
#     rank_global_te005_ppr  unit_id               region_name region_type  \
# 0                       1  LME_036           South China Sea         LME
# 1                       2  LME_032               Arabian Sea         LME
# 2                       3  LME_047            East China Sea         LME
# 3                       4  LME_034             Bay of Bengal         LME
# 4                       5   HS_077  Pacific, Eastern Central   High Seas
# 5                       6  LME_052            Sea of Okhotsk         LME
# 6                       7  LME_013          Humboldt Current         LME
# 7                       8  LME_028            Guinea Current         LME
# 8                       9  LME_027            Canary Current         LME
# 9                      10  LME_035          Gulf of Thailand         LME
# 10                     11   HS_071  Pacific, Western Central   High Seas
# 11                     12  LME_038            Indonesian Sea         LME
# 12                     13  LME_049          Kuroshio Current         LME
# 13                     14  LME_022                 North Sea         LME
# 14                     15  LME_048                Yellow Sea         LME
# 15                     16  LME_014          Patagonian Shelf         LME
# 16                     17  LME_050   Sea of Japan / East Sea         LME
# 17                     18  LME_003        California Current         LME
# 18                     19   HS_051     Indian Ocean, Western   High Seas
# 19                     20  LME_026         Mediterranean Sea         LME
# 20                     21  LME_024       Celtic-Biscay Shelf         LME
# 21                     22  LME_037          Sulu-Celebes Sea         LME
# 22                     23  LME_029          Benguela Current         LME
# 23                     24  LME_002            Gulf of Alaska         LME
# 24                     25  LME_046         New Zealand Shelf         LME
#
#     year  total_catch_tonnes  catch_tl_coverage_fraction   ppr_species  \
# 0   2019        1.110167e+07                         1.0  7.116845e+10
# 1   2019        5.436429e+06                         1.0  4.535545e+10
# 2   2019        5.649830e+06                         1.0  3.016282e+10
# 3   2019        6.697726e+06                         1.0  2.941850e+10
# 4   2019        8.606712e+05                         1.0  2.361100e+10
# 5   2019        4.800852e+06                         1.0  2.333543e+10
# 6   2019        7.390381e+06                         1.0  2.284241e+10
# 7   2019        4.469155e+06                         1.0  1.897625e+10
# 8   2019        5.771015e+06                         1.0  1.886955e+10
# 9   2019        2.615825e+06                         1.0  1.606373e+10
# 10  2019        5.718178e+05                         1.0  1.589874e+10
# 11  2019        2.883542e+06                         1.0  1.452653e+10
# 12  2019        3.090456e+06                         1.0  1.431826e+10
# 13  2019        2.717261e+06                         1.0  1.413020e+10
# 14  2019        2.658978e+06                         1.0  1.342322e+10
# 15  2019        1.589891e+06                         1.0  1.221958e+10
# 16  2019        2.586942e+06                         1.0  1.215499e+10
# 17  2019        1.037538e+06                         1.0  9.727375e+09
# 18  2019        3.778540e+05                         1.0  9.717573e+09
# 19  2019        1.487742e+06                         1.0  9.387160e+09
# 20  2019        1.139680e+06                         1.0  8.946927e+09
# 21  2019        1.731972e+06                         1.0  8.838268e+09
# 22  2019        1.592518e+06                         1.0  8.781048e+09
# 23  2019        1.102867e+06                         1.0  8.687784e+09
# 24  2019        4.311278e+05                         1.0  7.668473e+09
#
#     fraction_global_te005_ppr
# 0                    0.122191
# 1                    0.077872
# 2                    0.051787
# 3                    0.050509
# 4                    0.040538
# 5                    0.040065
# 6                    0.039219
# 7                    0.032581
# 8                    0.032398
# 9                    0.027580
# 10                   0.027297
# 11                   0.024941
# 12                   0.024583
# 13                   0.024261
# 14                   0.023047
# 15                   0.020980
# 16                   0.020869
# 17                   0.016701
# 18                   0.016684
# 19                   0.016117
# 20                   0.015361
# 21                   0.015175
# 22                   0.015076
# 23                   0.014916
# 24                   0.013166
#   region_type  units  catch_tonnes           ppr
# 0   High Seas     18  3.822570e+06  7.784740e+10
# 1         LME     66  9.529312e+07  5.045876e+11

# %% [markdown]
# ## Catch and aggregation reconciliation

# %%
validation = pd.read_csv(TABLES / 'validation.csv')
boolean_names = ['catch_reconciled', 'commercial_ppr_reconciled', 'functional_ppr_reconciled']
boolean_checks = validation[validation['check'].isin(boolean_names)].copy()
boolean_checks['passed'] = boolean_checks['value'].astype(str).str.lower().isin(['true', '1', '1.0'])
violation_checks = validation[validation['check'].str.endswith('jensen_violations')].copy()
violation_checks['value_numeric'] = pd.to_numeric(violation_checks['value'])
display(boolean_checks.groupby('check')['passed'].agg(['sum', 'count']))
display(violation_checks.groupby('check')['value_numeric'].agg(['sum', 'max']))
assert boolean_checks['passed'].all()
assert violation_checks['value_numeric'].eq(0).all()
# Out:
#                            sum  count
# check
# catch_reconciled            84     84
# commercial_ppr_reconciled   84     84
# functional_ppr_reconciled   84     84
#                               sum  max
# check
# commercial_jensen_violations    0    0
# functional_jensen_violations    0    0

# %% [markdown]
# ## Trophic-level matching coverage

# %%
coverage = pd.read_csv(TABLES / 'tl_coverage.csv')
route = coverage.groupby(['match_method', 'tl_source', 'match_confidence'], as_index=False).agg(
    taxa_rows=('taxa_count', 'sum'), catch_tonnes=('catch_tonnes', 'sum'))
route['catch_fraction_global'] = route['catch_tonnes'] / route['catch_tonnes'].sum()
display(route.sort_values('catch_tonnes', ascending=False))

low_coverage = summary.nsmallest(20, 'catch_tl_coverage_fraction')[
    ['unit_id', 'region_name', 'region_type', 'catch_tl_coverage_fraction',
     'missing_tl_catch_tonnes', 'taxa_count', 'matched_taxa_count']]
display(low_coverage)

route.set_index('match_method')['catch_fraction_global'].sort_values().plot.barh(
    color='#147D92', figsize=(8, 4.8))
plt.title('Global catch-weighted TL matching routes')
plt.xlabel('fraction of global catch')
plt.ylabel('')
plt.tight_layout()
plt.show()
# Out:
#             match_method                          tl_source match_confidence  \
# 1    exact_sea_around_us  Sea Around Us exploited organisms             high
# 0  exact_2020_supplement             2020 supplement MeanTL             high
#
#    taxa_rows  catch_tonnes  catch_fraction_global
# 1       7301  5.283413e+07               0.533055
# 0       6962  4.628155e+07               0.466945
#     unit_id               region_name region_type  catch_tl_coverage_fraction  \
# 0   LME_036           South China Sea         LME                         1.0
# 1   LME_032               Arabian Sea         LME                         1.0
# 2   LME_047            East China Sea         LME                         1.0
# 3   LME_034             Bay of Bengal         LME                         1.0
# 4    HS_077  Pacific, Eastern Central   High Seas                         1.0
# 5   LME_052            Sea of Okhotsk         LME                         1.0
# 6   LME_013          Humboldt Current         LME                         1.0
# 7   LME_028            Guinea Current         LME                         1.0
# 8   LME_027            Canary Current         LME                         1.0
# 9   LME_035          Gulf of Thailand         LME                         1.0
# 10   HS_071  Pacific, Western Central   High Seas                         1.0
# 11  LME_038            Indonesian Sea         LME                         1.0
# 12  LME_049          Kuroshio Current         LME                         1.0
# 13  LME_022                 North Sea         LME                         1.0
# 14  LME_048                Yellow Sea         LME                         1.0
# 15  LME_014          Patagonian Shelf         LME                         1.0
# 16  LME_050   Sea of Japan / East Sea         LME                         1.0
# 17  LME_003        California Current         LME                         1.0
# 18   HS_051     Indian Ocean, Western   High Seas                         1.0
# 19  LME_026         Mediterranean Sea         LME                         1.0
#
#     missing_tl_catch_tonnes  taxa_count  matched_taxa_count
# 0                       0.0         340                 340
# 1                       0.0         393                 393
# 2                       0.0         254                 254
# 3                       0.0         288                 288
# 4                       0.0          26                  26
# 5                       0.0         131                 131
# 6                       0.0         184                 184
# 7                       0.0         325                 325
# 8                       0.0         412                 412
# 9                       0.0         214                 214
# 10                      0.0          23                  23
# 11                      0.0         142                 142
# 12                      0.0         229                 229
# 13                      0.0         312                 312
# 14                      0.0         175                 175
# 15                      0.0         195                 195
# 16                      0.0         218                 218
# 17                      0.0         277                 277
# 18                      0.0          36                  36
# 19                      0.0         482                 482

# %% [markdown]
# ## Correct aggregation versus intentional Jensen-error aggregation
#
# The correct path sums taxon PPR before deriving group SPPR. The comparison path deliberately averages trophic level by catch before exponentiating. Convexity requires correct PPR to be at least the Jensen-error result, apart from numerical tolerance.

# %%
jensen = pd.read_csv(TABLES / 'jensen_comparison.csv')
global_bias = jensen.groupby('classification', as_index=False).agg(
    ppr_correct=('ppr_correct', 'sum'), ppr_jensen=('ppr_jensen', 'sum'))
global_bias['underestimate_fraction'] = 1 - global_bias['ppr_jensen'] / global_bias['ppr_correct']
display(global_bias)

regional_bias = jensen.groupby(['unit_id', 'region_name', 'classification'], as_index=False).agg(
    ppr_correct=('ppr_correct', 'sum'), ppr_jensen=('ppr_jensen', 'sum'))
regional_bias['underestimate_fraction'] = 1 - regional_bias['ppr_jensen'] / regional_bias['ppr_correct']
display(regional_bias.nlargest(25, 'underestimate_fraction'))
# Out:
#   classification   ppr_correct    ppr_jensen  underestimate_fraction
# 0     commercial  5.824350e+11  3.975511e+11                0.317433
# 1     functional  5.824350e+11  4.507182e+11                0.226148
#      unit_id                       region_name classification   ppr_correct  \
# 126  LME_047                    East China Sea     commercial  3.016282e+10
# 128  LME_048                        Yellow Sea     commercial  1.342322e+10
# 42   LME_005                    Gulf of Mexico     commercial  4.420193e+09
# 104  LME_036                   South China Sea     commercial  7.116845e+10
# 44   LME_006  Southeast U.S. Continental Shelf     commercial  9.925230e+08
# 139  LME_053                   West Bering Sea     functional  4.625977e+09
# 110  LME_039            North Australian Shelf     commercial  3.032256e+08
# 66   LME_017                North Brazil Shelf     commercial  2.556403e+09
# 64   LME_016                 East Brazil Shelf     commercial  1.769760e+09
# 100  LME_034                     Bay of Bengal     commercial  2.941850e+10
# 108  LME_038                    Indonesian Sea     commercial  1.452653e+10
# 98   LME_033                           Red Sea     commercial  1.036971e+09
# 56   LME_012                     Caribbean Sea     commercial  3.501525e+09
# 36   LME_002                    Gulf of Alaska     commercial  8.687784e+09
# 141  LME_054    Northern Bering - Chukchi Seas     functional  1.521808e+09
# 37   LME_002                    Gulf of Alaska     functional  8.687784e+09
# 114  LME_041     East-Central Australian Shelf     commercial  2.959347e+08
# 102  LME_035                  Gulf of Thailand     commercial  1.606373e+10
# 132  LME_050           Sea of Japan / East Sea     commercial  1.215499e+10
# 106  LME_037                  Sulu-Celebes Sea     commercial  8.838268e+09
# 46   LME_007  Northeast U.S. Continental Shelf     commercial  4.041020e+09
# 137  LME_052                    Sea of Okhotsk     functional  2.333543e+10
# 40   LME_004                Gulf of California     commercial  1.948429e+09
# 130  LME_049                  Kuroshio Current     commercial  1.431826e+10
# 94   LME_031            Somali Coastal Current     commercial  2.070392e+09
#
#        ppr_jensen  underestimate_fraction
# 126  1.319738e+10                0.562462
# 128  5.885518e+09                0.561542
# 42   2.150752e+09                0.513426
# 104  3.488221e+10                0.509864
# 44   4.950788e+08                0.501192
# 139  2.349763e+09                0.492050
# 110  1.551107e+08                0.488464
# 66   1.317406e+09                0.484664
# 64   9.470127e+08                0.464892
# 100  1.574499e+10                0.464793
# 108  7.789586e+09                0.463768
# 98   5.590031e+08                0.460927
# 56   1.926141e+09                0.449914
# 36   4.913192e+09                0.434471
# 141  8.612835e+08                0.434039
# 37   5.024531e+09                0.421656
# 114  1.711573e+08                0.421638
# 102  9.301313e+09                0.420974
# 132  7.129497e+09                0.413451
# 106  5.187495e+09                0.413064
# 46   2.432568e+09                0.398031
# 137  1.427268e+10                0.388368
# 40   1.200518e+09                0.383853
# 130  8.841832e+09                0.382479
# 94   1.279106e+09                0.382192

# %% [markdown]
# ## Final validation gate

# %%
assert len(summary) == metadata['unit_count'] == 84
assert summary['year'].nunique() == 1
positive_catch = summary['total_catch_tonnes'] > 0
assert summary.loc[positive_catch, 'catch_tl_coverage_fraction'].between(0, 1).all()
assert summary.loc[~positive_catch, 'catch_tl_coverage_fraction'].isna().all()
assert (summary['ppr_species'] - summary['ppr_commercial_correct']).abs().max() < 1e-4
assert (summary['ppr_species'] - summary['ppr_functional_correct']).abs().max() < 1e-4
assert summary['rank_global_te005_ppr'].tolist() == list(range(1, len(summary) + 1))
assert abs(summary['fraction_global_te005_ppr'].sum() - 1.0) < 1e-10
print('All global_te005 validation gates passed.')
# Out:
# All global_te005 validation gates passed.

# %% [markdown]
# ## Sources
#
# - Sea Around Us catch and spatial data: https://www.seaaroundus.org/data/
# - Sea Around Us tools/download guide: https://www.seaaroundus.org/tools-guide/
# - Pauly, D. & Christensen, V. (1995), *Primary production required to sustain global fisheries*, Nature 374:255-257.
# - Luong et al. (2020) supplementary workbook is used only for `MeanTL`; its alternative SPPR estimates are not used.
